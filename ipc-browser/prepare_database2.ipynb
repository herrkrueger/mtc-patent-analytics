# %% [markdown]
# # The Idea

# %% [markdown]
# > The CPC / IPC "*provides a hierarchical system of language independent symbols for the classification of patents and utility models according to the different areas of technology to which they pertain*".
#
# > To be able to identify each entry in the hierarchy, at least a **classificationn symbol** and "**level**"(CPC)/ "**kind**"(IPC) are specified.
#
# > We will iterate over the levels and create a table in our database containing the entries and the corresponding direct parent to establish  the hierarchy. We will then enrich our database with languages, dates, statistics ... which will be very useful for the visualization later on.

# %% [markdown]
# > **Summary**
# - Overview: IPC and CPC structure
# - IPC and CPC : from XML to database
#     - Level formatting
#     - Symbol formatting
# - IPC and CPC titles
# - IPC and CPC evolution - Technology Tree
# - IPC and CPC statistics
# - Run

# %% [markdown]
# # Overview: IPC and CPC structure

# %% [markdown]
# >A complete classification symbol comprises the combined symbols representing the section, class, subclass and main group or subgroup.

# %% [markdown]
# ![classidication](./static/classification1.PNG)

# %% [markdown]
# | Symbol | IPC   | CPC   |
# |------|------|------|
# |   **Section Symbol**  | one of the capital letters A through H | the addition of section 'Y' is unique to CPC.|
# |   **Class Symbol**  | section symbol followed by a two-digit number | - |
# |   **Subclass Symbol**  | class symbol followed by a capital letter | - |
# |   **Main Group Symbol**  | subclass symbol followed by a one- to three-digit number, the slash ("/") and the number 00 | subclass symbol followed by a one- to four-digit number, the slash ("/") and the number 00 |
# |   **Subgroup Symbol**  | subclass symbol followed by the one- to three-digit number of its main group, the slash ("/") and a number of at least two digits other than 00 | subclass symbol followed by the one- to four-digit number of its main group, the slash ("/") and a two- to six-digit numbers other than 00 |

# %% [markdown]
# >The hierarchical structure is shown in the following example:

# %% [markdown]
# ![classidication](./static/classification2.PNG)

# %% [markdown]
# > **A new version of the IPC enters into force each year on January 1. The CPC is updated multiple times a years. Therefore the links have to be updated in the config.py!**

# %% [markdown]
# # IPC and CPC : from XML to database

# %%
# to open the xml files
import requests, zipfile, io, os
import tempfile

# to connect to database
from sqlalchemy import create_engine
from sqlalchemy import inspect
from sqlalchemy.engine.url import URL
from sqlalchemy.types import String
import sqlite3

# to read, write and process the data
import pandas as pd
from lxml import etree as ET
from sklearn import preprocessing
import re
import time
import numpy as np

# initiate configuration class and connect to database
from config import config
config = config()
reqsD = config.connect_to_database()
fileD = config.files()
engine = create_engine(str(URL(**reqsD)) + '/patent_classification')
conn = engine.connect()
inspector = inspect(engine)
# check for schema and table in database
#if scheme in inspector.get_table_names():
#    conn.execute('DROP TABLE patent_classification.' + scheme)

# %% [markdown]
# >We iterate over the entries and save the clasification hierarchy i.e.
# - classification symbols as indices
# - kinds
# - direct parents.

# %%
# takes approximately 15 min
def importer(scheme, fileD, schemaL, engine, conn, to_sql):
    with tempfile.TemporaryDirectory() as directory:

        # unzip...
        url = fileD[scheme]
        r = requests.get(url)
        z = zipfile.ZipFile(io.BytesIO(r.content))
        z.extractall(directory)
        filename = os.listdir(directory)[0] #en and fr version available, for the hierarchy struture only need one 

        # ...and parse file
        parser = ET.XMLParser(remove_blank_text=True)
        path = os.path.join(directory, filename)
        tree = ET.parse(path, parser=parser)
        root = tree.getroot()

        # list of parent entries to iterate over
        parentL=[root]

        for parent in parentL:
            # create dataframe for each level and parent
            df = pd.DataFrame(columns=['kind', 'parent'])

            # iterate over children entries
            for entry in parent.iterchildren(tag='{http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry'):

                # add children to list of parents  
                parentL.append(entry)

                # save classification symbol
                symbol = entry.attrib['symbol']
                
                # get classification level 
                kind = entry.attrib['kind']
                
                # save kind and symbol of direct parent
                if kind == "s":
                    # for entries of level 1 save "IPC" as parent
                    df.loc[symbol, 'kind']= kind
                    df.loc[symbol, 'parent']= scheme.upper()
                elif kind not in ['t', 'i', 'g', 'n']:
                    # save only relevant entries 
                    if parent.tag == '{http://www.wipo.int/classifications/ipc/masterfiles}ipcEntry':
                        df.loc[symbol, 'kind']= kind
                        df.loc[symbol, 'parent']= parent.attrib['symbol']
                        
            # write to database
            if to_sql == 'yes':
                df.to_sql(scheme, engine, if_exists='append', schema='patent_classification', index=True, index_label="symbol")

# %% [markdown]
# ### Level formatting

# %% [markdown]
# > Additionally to the alphanumeric "kinds" of the IPC ("s" for section, "c" for class, "u" for subclass, "m" for main group and 1-9, "A", "B" for sub groups), we will use the numeric equivalent "levels" of the CPC (2-19) to be able to iterate over a well-ordered set.

# %%
def add_levels(scheme, engine, to_sql):
    
    # save "levels" by mapping corresponding "kinds"
    df = pd.read_sql_table(scheme, engine, schema='patent_classification', index_col='symbol')
    df['level'] = df['kind']
    kind_to_levelD = {'s': 2, 'c': 3, 'u': 4, 'm' :5, '1': 6, '2': 7, '3': 8, '4': 9, '5': 10,
                      '6': 11, '7': 12, '8': 13, '9': 14, 'A': 15, 'B': 16, 'C':17}
    df.replace({"level": kind_to_levelD}, inplace=True)
    if to_sql == 'yes':
        df.to_sql(scheme, engine, if_exists='replace', schema='patent_classification', index=True)

# %% [markdown]
# ### Symbol formatting

# %% [markdown]
# > The symbols in the xml files have not the format shown in the exemple from the beginin: it's H01F0001053000 and not H01F1/053. So we add the short format for the symbols.

# %%
# transforms H01F0001053000 to H01F1/053
def formatting_symbols(x):
    # for section, class, subclass return symbol
    if len(x)<= 4:
        return x
    else:
        # for group remove leading and trailing zeros
        x = x[:4] + str(int(x[4:8])) + '/' + x[8:].rstrip('0')
        
        if x[-1] == '/':
            return x + '00'
        else:
            return x

def add_symbols_short(scheme, engine, to_sql):
    df = pd.read_sql_table(scheme, engine, schema='patent_classification', index_col='symbol')
    df['symbol_short'] = list(map(lambda x: formatting_symbols(x), df.index.tolist()))
    df['parent_short'] = df['parent'].apply(lambda x: formatting_symbols(x))

    if to_sql == 'yes':
        df.to_sql(scheme, engine, if_exists='replace', schema='patent_classification', index=True)

# %% [markdown]
# # IPC and CPC titles

# %% [markdown]
# > We choose to not extract the titles directly from the xml files (because the syntax is not practical). The txt files containing the IPC/ CPC scheme titles in authentic languages look as follow (except that for the CPC the short symbol format is used).

# %%
titles = pd.read_csv(fileD['ipc_en'][0], sep='\t', header=None)
print(titles.head(10))
# Out:
#                 0                                                  1
# 0               A                                  HUMAN NECESSITIES
# 1             A01  AGRICULTURE; FORESTRY; ANIMAL HUSBANDRY; HUNTI...
# 2            A01B  SOIL WORKING IN AGRICULTURE OR FORESTRY; PARTS...
# 3  A01B0001000000  Hand tools (edge trimmers for lawns A01G000306...
# 4  A01B0001020000                                    Spades; Shovels
# 5  A01B0001040000                                         with teeth
# 6  A01B0001060000                             Hoes; Hand cultivators
# 7  A01B0001080000                                with a single blade
# 8  A01B0001100000                            with two or more blades
# 9  A01B0001120000                    with blades provided with teeth

# %% [markdown]
# >We concatenate the txt files from A to H (A to Y for the CPC) to a dataframe with the symbols as indices and a column of titles, which we then join to the database table.

# %%
def get_titles(scheme, schemeD, index, engine):

    for language in list(schemeD.keys()):

        # concatenate txt files to dataframe of titles 
        titles= []

        # ...for the cpc it's a txt file that we have to unzip first
        if scheme == 'cpc':
            with tempfile.TemporaryDirectory() as directory:
                r = requests.get(schemeD[language])
                z = zipfile.ZipFile(io.BytesIO(r.content))
                z.extractall(directory)
                filenameL = [file for file in os.listdir(directory) if file.endswith('.txt')]
                for filename in filenameL:
                    path = os.path.join(directory, filename)
                    df = pd.read_csv(path,  sep='\t', header=None, names=[index, 'title_' + language])
                    titles.append(df)
        else:
            for filename in schemeD[language]:
                r = requests.get(filename)
                byte = r.content
                s=str(byte,'utf-8')
                data = StringIO(s) 
                df = pd.read_csv(data,  sep='\t', header=None, names=[index, 'title_' + language])
                titles.append(df)
        df_titles = pd.concat(titles, axis=0, ignore_index=True)
        df_titles.drop_duplicates(subset=index, keep='last', inplace=True)

        # append titles to database
        df = pd.read_sql_table(scheme, engine, schema='patent_classification', index_col=index)
        df = df.join(df_titles.set_index(index))
        return df
        #df.to_sql(scheme, engine, if_exists='replace', schema='patent_classification', index=True)

# %% [markdown]
# # IPC and CPC evolution - Technology Tree

# %% [markdown]
# > To trace the development of the technology fields over time, we save a creation date for every symbol.

# %%
def pc_evolution(scheme, index, engine, fileD, to_sql):
    
    # read table from database
    df = pd.read_sql_table(scheme, engine, schema='patent_classification', index_col=index)

    # read inventory of IPC/CPC ever used symbols with creation date
    inventory = fileD[ scheme + '_inventory']
    
    # ...for the cpc it's a txt file that we have to unzip first
    if scheme == 'cpc':
        with tempfile.TemporaryDirectory() as directory:
            r = requests.get(inventory)
            z = zipfile.ZipFile(io.BytesIO(r.content))
            z.extractall(directory)
            filename = [file for file in os.listdir(directory) if file.endswith('.txt')][0]
            path = os.path.join(directory, filename)
            
            pc_inventory = pd.read_csv(path, sep='\t', names= [index, 'creation_date', 'expiration_date'], usecols=[0,1])
    
    # ...for the ipc we can read it directly
    else:
        pc_inventory = pd.read_csv(inventory, sep=';', names= [index, 'creation_date', 'expiration_date'], usecols=[0,1])
    
    # we join the tables...
    df = df.join(pc_inventory.set_index(index))
    
    # ...and fill the creation dates of the section and class symbols
    if scheme == 'cpc':
        creation_data = '2013-01-01'
    else:
        creation_data = 19680901
    df.fillna(value= {'creation_date': creation_data}, inplace=True)
    
    if to_sql == 'yes':
        df.to_sql(scheme, engine, if_exists='replace', schema='patent_classification', index=True, dtype={'creation_date':String()})

# %% [markdown]
# # IPC and CPC statistics

# %% [markdown]
# > The WIPO offers a summary table with the number of classes, subclasses, main groups, subgroups and groups (i.e. sum of main groups and subgroups) for each section. This statistics are only given at the highest hierachical level. The tree allows us to have statistcs for each entry at each hierarchical level.

# %% [markdown]
# > We trace all the possible branches of the tree i.e. the paths of all the symbols from main groups and subgroups. Then we can "count" for each symbol of each level in how many paths it appears and deduce a size for each entry of the tree.

# %%
# returns a list with the paths of all symbols from main groups and subgroups as lists of symbols
# takes approximately 30 min
def get_paths(scheme, engine):
    
    df = pd.read_sql_table(scheme, engine, schema='patent_classification')
    df['level'] = pd.to_numeric(df['level'])
    grouped_level = df.groupby('level')
    
    pathsL = []
    
    # iterte df over rows
    for index, row in df.iterrows():
        key = row['symbol']
        level = int(row['level'])
        
        # select only symbols of main groups and subgroups
        if level >4:
            path=[key]
            # trace path by appending successively the corresponding direct parent to a list
            for i in range(level , 2, -1):
                group = grouped_level.get_group(i)
                try:
                    parent = group[group['symbol'] == key]['parent'].iloc[0]
                    key = parent
                    path.append(parent)
                except:
                    print(key)
                    pass
            path = path[::-1]
            pathsL.append(path)
    df = pd.DataFrame(pathsL)
    df.to_csv(scheme + '_statistics.csv')

# %%
def pc_statistics(pathsL, scheme, engine, to_sql):
    
    # convert list of paths to dataframe and fill paths with 0 to reach maximal lenght
    paths_df = pd.read_csv('ipc_statistics.csv', index_col=0)
    paths_df.fillna('0', inplace=True)

    stat=[]
    # iterate df over columns in order to group by each level
    for i in range(paths_df.shape[1]):
        grouped = paths_df.groupby([str(j) for j in range(i+1)])
        
        # save symbol and it's size to list
        for key in grouped.groups.keys():
            if '0' not in key:
                stat.append([key[-1], len(grouped.get_group(key))])

    # convert to df with the symbols and for each symbol a value corresponding to the number of groups it contains
    stat_df = pd.DataFrame(stat, columns=['symbol', 'size'])
    
    # add size in % 
    stat_df['size_percent'] = round(stat_df['size'] * 100 / 74503, 3)
    
    # append statistics to database
    df = pd.read_sql_table(scheme, engine, schema='patent_classification')
    #pathsL = get_paths(df, engine)
    df = df.set_index('symbol').join(stat_df.set_index('symbol'))
    
    # add normalised size for each group of children for visualization
    df['size_normalised'] = df['size']
    grouped = df.groupby('parent')
    for key in grouped.groups.keys():
        group = grouped.get_group(key)
        x = group['size_normalised'].values.reshape(-1, 1)
        min_max_scaler = preprocessing.MinMaxScaler(feature_range=(3, 13))
        x_scaled = min_max_scaler.fit_transform(x)
        index = group.index.values
        df.loc[index, 'size_normalised'] = x_scaled
    
    if to_sql == 'yes':
        df.to_sql(scheme, engine, if_exists='replace', schema='patent_classification')

# %% [markdown]
# > Sanity checks for the statistics:

# %%
def sanity_check(df):
    grouped = df.groupby('level')
    for key in grouped.groups.keys():
        group = grouped.get_group(key)
        size = group['size'].sum()
        print(key, size)

# %% [markdown]
# # From postgresql to sqlite

# %%
def postgresql_to_sqlite(scheme, engine):
    df = pd.read_sql_table(scheme, engine, schema='patent_classification')
    conn2 = sqlite3.connect('./patent-classification.db')
    df.to_sql(name=scheme, schema='patent-classification', index=False, con=conn2, if_exists='replace')

# %%
conn2 = sqlite3.connect('./patent-classification.db')
import_df = pd.read_sql_query("SELECT * FROM" + scheme, conn2)
print(import_df.head)
# Out:
# <bound method NDFrame.head of                symbol kind          parent  level symbol_short parent_short  \
# 76895  Blindage d'appareils ou de composants contre l...    19680901.0     1
# 76896  Dispositions pour améliorer la sécurité de fon...    19680901.0     1
# 76897  Combinaisons d'un récepteur de radio ou de tél...    19680901.0     2
# 76898                                 avec des véhicules    19680901.0     1
# 76899  Appareils ou procédés spécialement adaptés à l...    19680901.0     5
# 76900                         Introduction de composants    19680901.0     1
# 76901                              Montage de composants    19680901.0     1
# 76902                                Câblage par machine    19680901.0     1
# 76903           Contrôle de la fabrication des ensembles    19680901.0     1
# 76904  MATIÈRE NON PRÉVUE AILLEURS DANS LA PRÉSENTE S...      19680901     1
# 76905  MATIÈRE NON PRÉVUE AILLEURS DANS LA PRÉSENTE S...    20060101.0     1
# 76906  Matière non prévue ailleurs dans la présente s...    20060101.0     1
#
#        size_percent
# 0            12.327
# 1             2.111
# 2             0.301
# 3             0.017
# 4             0.003
# 5             0.001
# 6             0.007
# 7             0.001
# 8             0.001
# 9             0.001
# 10            0.001
# 11            0.003
# 12            0.001
# 13            0.001
# 14            0.001
# 15            0.001
# 16            0.052
# 17            0.052
# 18            0.052
# 19            0.052
# 20            0.001
# 21            0.013
# 22            0.007
# 23            0.001
# 24            0.001
# 25            0.001
# 26            0.001
# 27            0.005
# 28            0.001
# 29            0.001
# ...             ...
# 76877         0.001
# 76878         0.001
# 76879         0.007
# 76880         0.003
# 76881         0.001
# 76882         0.001
# 76883         0.001
# 76884         0.015
# 76885         0.008
# 76886         0.001
# 76887         0.003
# 76888         0.001
# 76889         0.001
# 76890         0.001
# 76891         0.003
# 76892         0.001
# 76893         0.001
# 76894         0.001
# 76895         0.001
# 76896         0.001
# 76897         0.003
# 76898         0.001
# 76899         0.007
# 76900         0.001
# 76901         0.001
# 76902         0.001
# 76903         0.001
# 76904         0.001
# 76905         0.001
# 76906         0.001
#
# [76907 rows x 11 columns]>

# %% [markdown]
# # Run

# %%
import time
scheme = input('Choose between cpc or ipc: ').lower()
to_sql = input('Overwrite database?(yes/no): ').lower()


# df with symbols, kinds and direct parents..
# takes approximately 15 min
#importer(scheme, fileD, schemaL, engine, conn, to_sql)

# ..add column for levels
# takes less than 1 min
#add_levels(scheme, engine, to_sql)

# ..add column for short symbols
# takes less than 1 min
#add_symbols_short(scheme, engine, to_sql)

if scheme == 'ipc':
    schemeD = {'en' : fileD['ipc_en'], 'fr': fileD['ipc_fr']}
    index = 'symbol'
elif scheme == 'cpc':
    schemeD = {'en' : fileD['cpc_en']}
    index = 'symbol_short'

# ..add columns for titles
# takes less than 1 min
get_titles(scheme, schemeD, index, engine)

# ..add columns for creation dates
# takes less than 1 min
#pc_evolution(scheme, index, engine, fileD, to_sql)

# ..add columns for sizes i.e. number of groups contained (in % and normalised)
# takes approximately 30 min
#pathsL = get_paths(scheme, engine)
# takes less than 1 min
#pc_statistics(pathsL, scheme, engine, to_sql)

# from postgresql to sqlite
#postgresql_to_sqlite(scheme, engine)
# Out:
# Choose between cpc or ipc: cpc
# Overwrite database?(yes/no): yes
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x121ac7240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='www.cooperativepatentclassification.org', port=443): Max retries exceeded with url: /cpc/interleaved/CPCTitleList201908.zip (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x121ac7240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-26-bcb43c8ebf00> in <module>
#      25 # ..add columns for titles
#      26 # takes less than 1 min
# ---> 27 get_titles(scheme, schemeD, index, engine)
#      28
#      29 # ..add columns for creation dates
#
# <ipython-input-24-a9a5f438955a> in get_titles(scheme, schemeD, index, engine)
#       9         if scheme == 'cpc':
#      10             with tempfile.TemporaryDirectory() as directory:
# ---> 11                 r = requests.get(schemeD[language])
#      12                 z = zipfile.ZipFile(io.BytesIO(r.content))
#      13                 z.extractall(directory)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.cooperativepatentclassification.org', port=443): Max retries exceeded with url: /cpc/interleaved/CPCTitleList201908.zip (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x121ac7240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %% [markdown]
# ### Colors for branches

# %%
import numpy as np
creation_date = df['creation_date'].unique().tolist()
creation_year = [date[:4] for date in creation_date]
creation_yearL = sorted(list(map(int, creation_year )))
print(creation_yearL)
# Out:
# [1968, 1968, 1974, 1980, 1985, 1990, 1995, 2000, 2006, 2007, 2007, 2008, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
for date in creation_date:
    print('--------------------------------', date)
    print(df[df['creation_date'] == date].shape)
    print(df[df['creation_date'] == date].head(10))
# Out:
# -------------------------------- 19680901
# (139, 11)
#      symbol kind parent  level symbol_short parent_short  \
# 0         A    s    IPC      2            A          IPC
# 1       A01    c      A      3          A01            A
# 1680    A21    c      A      3          A21            A
# 1846    A22    c      A      3          A22            A
# 1919    A23    c      A      3          A23            A
# 2717    A24    c      A      3          A24            A
# 2972    A41    c      A      3          A41            A
# 3235    A42    c      A      3          A42            A
# 3282    A43    c      A      3          A43            A
# 3697    A44    c      A      3          A44            A
#
#                                                title_en  \
# 0                                     HUMAN NECESSITIES
# 1     AGRICULTURE; FORESTRY; ANIMAL HUSBANDRY; HUNTI...
# 1680  BAKING; EQUIPMENT FOR MAKING OR PROCESSING DOU...
# 1846  BUTCHERING; MEAT TREATMENT; PROCESSING POULTRY...
# 1919  FOODS OR FOODSTUFFS; THEIR TREATMENT, NOT COVE...
# 2717   TOBACCO; CIGARS; CIGARETTES; SMOKERS' REQUISITES
# 2972                                    WEARING APPAREL
# 3235                                           HEADWEAR
# 3282                                           FOOTWEAR
# 3697                            HABERDASHERY; JEWELLERY
#
#                                                title_fr creation_date  size  \
# 0                        NÉCESSITÉS COURANTES DE LA VIE      19680901  9184
# 1     AGRICULTURE; SYLVICULTURE; ÉLEVAGE; CHASSE; PI...      19680901  1573
# 1680  CUISSON AU FOUR; MATÉRIEL POUR LA PRÉPARATION ...      19680901   166
# 1846  BOUCHERIE; TRAITEMENT DE LA VIANDE; TRAITEMENT...      19680901    63
# 1919  ALIMENTS OU PRODUITS ALIMENTAIRES; LEUR TRAITE...      19680901   777
# 2717  TABAC; CIGARES; CIGARETTES; ARTICLES POUR FUMEURS      19680901   237
# 2972                                          VÊTEMENTS      19680901   253
# 3235                                        CHAPELLERIE      19680901    45
# 3282                                         CHAUSSURES      19680901   386
# 3697                               MERCERIE; BIJOUTERIE      19680901   128
#
#       size_percent
# 0           12.327
# 1            2.111
# 1680         0.223
# 1846         0.085
# 1919         1.043
# 2717         0.318
# 2972         0.340
# 3235         0.060
# 3282         0.518
# 3697         0.172
# -------------------------------- 19680901.0
# (40501, 11)
#             symbol kind          parent  level symbol_short parent_short  \
# 2             A01B    u             A01      4         A01B          A01
# 3   A01B0001000000    m            A01B      5     A01B1/00         A01B
# 4   A01B0001020000    1  A01B0001000000      6     A01B1/02     A01B1/00
# 5   A01B0001040000    2  A01B0001020000      7     A01B1/04     A01B1/02
# 6   A01B0001060000    1  A01B0001000000      6     A01B1/06     A01B1/00
# 7   A01B0001080000    2  A01B0001060000      7     A01B1/08     A01B1/06
# 8   A01B0001100000    2  A01B0001060000      7      A01B1/1     A01B1/06
# 9   A01B0001120000    2  A01B0001060000      7     A01B1/12     A01B1/06
# 10  A01B0001140000    2  A01B0001060000      7     A01B1/14     A01B1/06
# 11  A01B0001160000    1  A01B0001000000      6     A01B1/16     A01B1/00
#
#                                              title_en  \
# 2   SOIL WORKING IN AGRICULTURE OR FORESTRY; PARTS...
# 3   Hand tools (edge trimmers for lawns A01G000306...
# 4                                     Spades; Shovels
# 5                                          with teeth
# 6                              Hoes; Hand cultivators
# 7                                 with a single blade
# 8                             with two or more blades
# 9                     with blades provided with teeth
# 10                                    with teeth only
# 11                          Tools for uprooting weeds
#
#                                              title_fr creation_date  size  \
# 2   TRAVAIL DE LA TERRE EN AGRICULTURE OU EN SYLVI...    19680901.0   224
# 3   Outils à main (tranche-bordures pour pelouses ...    19680901.0    13
# 4                                      Bêches; Pelles    19680901.0     2
# 5                                           dentelées    19680901.0     1
# 6                              Houes; Bineuses à main    19680901.0     5
# 7                                       à lame unique    19680901.0     1
# 8                                   à plusieurs lames    19680901.0     1
# 9                                   à lames dentelées    19680901.0     1
# 10                                 à dents uniquement    19680901.0     1
# 11                                          Sarcloirs    19680901.0     2
#
#     size_percent
# 2          0.301
# 3          0.017
# 4          0.003
# 5          0.001
# 6          0.007
# 7          0.001
# 8          0.001
# 9          0.001
# 10         0.001
# 11         0.003
# -------------------------------- 19740701.0
# (6337, 11)
#              symbol kind          parent  level symbol_short parent_short  \
# 15   A01B0001240000    1  A01B0001000000      6     A01B1/24     A01B1/00
# 41   A01B0003421000    4  A01B0003420000      9    A01B3/421     A01B3/42
# 42   A01B0003426000    4  A01B0003420000      9    A01B3/426     A01B3/42
# 183  A01B0059041000    2  A01B0059040000      7   A01B59/041    A01B59/04
# 252  A01C0003080000    2  A01C0003060000      7     A01C3/08     A01C3/06
# 471  A01D0041140000    2  A01D0041120000      7    A01D41/14    A01D41/12
# 490  A01D0044000000    m            A01D      5    A01D44/00         A01D
# 491  A01D0044020000    1  A01D0044000000      6    A01D44/02    A01D44/00
# 503  A01D0046000000    m            A01D      5    A01D46/00         A01D
# 504  A01D0046020000    1  A01D0046000000      6    A01D46/02    A01D46/00
#
#                                               title_en  \
# 15                       for treating meadows or lawns
# 41            with a headstock frame made in one piece
# 42    with a headstock frame made of two or more parts
# 183  preventing or limiting side-play of implements...
# 252              for manure already laying on the soil
# 471                                      Mowing tables
# 490  Harvesting of underwater plants, e.g. harvesti...
# 491                                           of laver
# 503  Picking of fruits, vegetables, hops, or the li...
# 504                                            of hops
#
#                                               title_fr creation_date  size  \
# 15          pour le traitement de prairies ou pelouses    19740701.0     1
# 41          avec support d'attelage en une seule pièce    19740701.0     1
# 42        avec support d'attelage en plusieurs parties    19740701.0     1
# 183  avec prévention ou limitation du jeu latéral d...    19740701.0     1
# 252     pour engrais de ferme déjà disposés sur le sol    19740701.0     1
# 471                                    Tables de coupe    19740701.0     2
# 490  Récolte de la flore subaquatique, p.ex. récolt...    19740701.0     2
# 491                             des algues comestibles    19740701.0     1
# 503  Cueillette de fruits, légumes, houblon ou de p...    19740701.0    18
# 504                                         du houblon    19740701.0     1
#
#      size_percent
# 15          0.001
# 41          0.001
# 42          0.001
# 183         0.001
# 252         0.001
# 471         0.003
# 490         0.003
# 491         0.001
# 503         0.024
# 504         0.001
# -------------------------------- 19850101.0
# (4268, 11)
#              symbol kind          parent  level symbol_short parent_short  \
# 232  A01B0073020000    1  A01B0073000000      6    A01B73/02    A01B73/00
# 233  A01B0073040000    2  A01B0073020000      7    A01B73/04    A01B73/02
# 234  A01B0073060000    2  A01B0073020000      7    A01B73/06    A01B73/02
# 289  A01C0019020000    1  A01C0019000000      6    A01C19/02    A01C19/00
# 290  A01C0019040000    1  A01C0019000000      6    A01C19/04    A01C19/00
# 380  A01D0034000000    m            A01D      5    A01D34/00         A01D
# 383  A01D0034000000    m            A01D      5    A01D34/00         A01D
# 384  A01D0034000000    m            A01D      5    A01D34/00         A01D
# 385  A01D0034000000    m            A01D      5    A01D34/00         A01D
# 387  A01D0034020000    2  A01D0034010000      7    A01D34/02    A01D34/01
#
#                                               title_en  \
# 232                                     Folding frames
# 233                   foldable about a horizontal axis
# 234                     foldable about a vertical axis
# 289                                         by a motor
# 290                         by a ground-engaging wheel
# 380  Harvesters or mowers for grass, cereals or oth...
# 383  Harvesters or mowers for grass, cereals or oth...
# 384  Mowers (combined with apparatus performing add...
# 385  Mowers (combined with apparatus performing add...
# 387                       having reciprocating cutters
#
#                                               title_fr creation_date  size  \
# 232                                      Bâtis pliants    19850101.0     3
# 233              repliables autour d'un axe horizontal    19850101.0     1
# 234                repliables autour d'un axe vertical    19850101.0     1
# 289                               à l'aide d'un moteur    19850101.0     1
# 290           à l'aide d'une roue en prise avec le sol    19850101.0     1
# 380  Moissonneuses ou faucheuses pour herbages, cér...    19850101.0    72
# 383  Faucheuses (combinées avec des appareils perme...    19850101.0    72
# 384  Moissonneuses ou faucheuses pour herbages, cér...    19850101.0    72
# 385  Faucheuses (combinées avec des appareils perme...    19850101.0    72
# 387     comportant des couteaux à mouvement alternatif    19850101.0    29
#
#      size_percent
# 232         0.004
# 233         0.001
# 234         0.001
# 289         0.001
# 290         0.001
# 380         0.097
# 383         0.097
# 384         0.097
# 385         0.097
# 387         0.039
# -------------------------------- 20060101.0
# (1316, 11)
#               symbol kind parent  level symbol_short parent_short  \
# 236   A01B0076000000    m   A01B      5    A01B76/00         A01B
# 276   A01C0014000000    m   A01C      5    A01C14/00         A01C
# 1056  A01J0099000000    m   A01J      5    A01J99/00         A01J
# 1299  A01K0099000000    m   A01K      5    A01K99/00         A01K
# 394  avec des moyens pour décharger les produits fa...    20000101.0     1
# 396  comportant des tringles porte-lames à mouvemen...    20000101.0     1
# 416  comportant des couteaux entraînés pour oscille...    20000101.0     2
# 417                   comportant des couteaux rotatifs    20000101.0    34
# 418                       sous forme de fils flexibles    20000101.0     1
# 424  avec des moyens pour décharger les produits fa...    20000101.0     1
# 427  avec des organes coupants reliés de façon pivo...    20000101.0     1
# 439                               à plusieurs couteaux    20000101.0     1
#
#      size_percent
# 381         0.001
# 386         0.090
# 394         0.001
# 396         0.001
# 416         0.003
# 417         0.046
# 418         0.001
# 424         0.001
# 427         0.001
# 439         0.001
# -------------------------------- 19950101.0
# (2860, 11)
#              symbol kind          parent  level symbol_short parent_short  \
# 382  A61K0103200000    1  A61K0103000000      6    A61K103/2   A61K103/00
# 605  A01D0082020000    1  A01D0082000000      6    A01D82/02    A01D82/00
# 607  A01D0084020000    1  A01D0084000000      6    A01D84/02    A01D84/00
# 630  A01D0101000000    m            A01D      5   A01D101/00         A01D
# 632  A01D0101000000    m            A01D      5   A01D101/00         A01D
# 633  A01D0101000000    m            A01D      5   A01D101/00         A01D
# 634  A01D0101000000    m            A01D      5   A01D101/00         A01D
# 743  A01G0003025000    2  A01G0003020000      7    A01G3/025     A01G3/02
# 744  A01G0003033000    2  A01G0003020000      7    A01G3/033     A01G3/02
# 745  A01G0003037000    3  A01G0003033000      8    A01G3/037    A01G3/033
#
#                                               title_en  \
# 382                                             Indium
# 605                      Rollers for crop conditioners
# 607                                with flexible tools
# 630  Indexing scheme associated with group A01D0034...
# 632  Indexing scheme associated with group A01D0034...
# 633                                        Lawn-mowers
# 634                                        Lawn-mowers
# 743               having elongated or extended handles
# 744                         having motor-driven blades
# 745          the driving means being an electric motor
#
#                                               title_fr creation_date  size  \
# 382                                             Indium    19950101.0     1
# 605  Rouleaux pour machines de traitement de la réc...    19950101.0     1
# 607                          avec des outils flexibles    19950101.0     1
# 630  Schéma d'indexation associé au groupe A01D0034...    19950101.0     1
# 632                                  Tondeuses à gazon    19950101.0     1
# 633  Schéma d'indexation associé au groupe A01D0034...    19950101.0     1
# 634                                  Tondeuses à gazon    19950101.0     1
# 743          avec des poignées allongées ou prolongées    19950101.0     1
# 744            avec des lames entraînées par un moteur    19950101.0     2
# 745  le moyen d'entraînement étant un moteur électr...    19950101.0     1
#
#      size_percent
# 382         0.001
# 605         0.001
# 607         0.001
# 630         0.001
# 632         0.001
# 633         0.001
# 634         0.001
# 743         0.001
# 744         0.003
# 745         0.001
# -------------------------------- 19800101.0
# (5659, 11)
#              symbol kind          parent  level symbol_short parent_short  \
# 518  A01D0046260000    1  A01D0046000000      6    A01D46/26    A01D46/00
# 519  A01D0046280000    1  A01D0046000000      6    A01D46/28    A01D46/00
# 529  A01D0057030000    3  A01D0057020000      8    A01D57/03    A01D57/02
# 587  A01D0076000000    m            A01D      5    A01D76/00         A01D
# 588  A01D0076000000    m            A01D      5    A01D76/00         A01D
# 589  A01D0076000000    m            A01D      5    A01D76/00         A01D
# 590  A01D0076000000    m            A01D      5    A01D76/00         A01D
# 591  A01D0078000000    m            A01D      5    A01D78/00         A01D
# 592  A01D0078020000    1  A01D0078000000      6    A01D78/02    A01D78/00
# 593  A01D0078040000    2  A01D0078020000      7    A01D78/04    A01D78/02
#
#                                               title_en  \
# 518  Devices for shaking trees or shrubs; Fruit cat...
# 519  Vintaging machines, i.e. grape harvesting mach...
# 529  with supplementary controlled movement of the ...
# 587                       Haymakers; Crop conditioners
# 588                       Haymakers; Crop conditioners
# 589  Haymakers with tines that are stationary with ...
# 590  Haymakers with tines that are stationary with ...
# 591  Haymakers with tines moving with respect to th...
# 592  with tine-carrying bars or equivalent members ...
# 593  the tine-carrying members moving obliquely or ...
#
#                                               title_fr creation_date  size  \
# 518  Dispositifs pour secouer les arbres ou les arb...    19800101.0     1
# 519                               Machines à vendanger    19800101.0     1
# 529  comportant un mouvement commandé supplémentair...    19800101.0     1
# 587     Faneuses; Machines de traitement de la récolte    19800101.0     1
# 588  Faneuses à dents qui restent fixes par rapport...    19800101.0     1
# 589     Faneuses; Machines de traitement de la récolte    19800101.0     1
# 590  Faneuses à dents qui restent fixes par rapport...    19800101.0     1
# 591  Faneuses à dents mobiles par rapport à la mach...    19800101.0    11
# 592  à barres porte-dents ou organes équivalents qu...    19800101.0     2
# 593  les organes porte-dents se déplaçant obliqueme...    19800101.0     1
#
#      size_percent
# 518         0.001
# 519         0.001
# 529         0.001
# 587         0.001
# 588         0.001
# 589         0.001
# 590         0.001
# 591         0.015
# 592         0.003
# 593         0.001
# -------------------------------- 20090101.0
# (291, 11)
#               symbol kind          parent  level symbol_short parent_short  \
# 629   A01D0093000000    m            A01D      5    A01D93/00         A01D
# 1639  A01N0065030000    1  A01N0065000000      6    A01N65/03    A01N65/00
# 1640  A01N0065040000    1  A01N0065000000      6    A01N65/04    A01N65/00
# 1641  A01N0065060000    1  A01N0065000000      6    A01N65/06    A01N65/00
# 1642  A01N0065080000    1  A01N0065000000      6    A01N65/08    A01N65/00
# 1643  A01N0065100000    2  A01N0065080000      7     A01N65/1    A01N65/08
# 1644  A01N0065120000    2  A01N0065080000      7    A01N65/12    A01N65/08
# 1645  A01N0065140000    2  A01N0065080000      7    A01N65/14    A01N65/08
# 1646  A01N0065160000    2  A01N0065080000      7    A01N65/16    A01N65/08
# 1647  A01N0065180000    2  A01N0065080000      7    A01N65/18    A01N65/08
#
#                                                title_en  \
# 629   Harvesting apparatus not provided for in other...
# 1639                                              Algae
# 1640    Pteridophyta [fern allies]; Filicophyta [ferns]
# 1641          Coniferophyta [gymnosperms], e.g. cypress
# 1642                       Magnoliopsida [dicotyledons]
# 1643  Apiaceae or Umbelliferae [Carrot family], e.g....
# 1644  Asteraceae or Compositae [Aster or Sunflower f...
# 1645  Celastraceae [Staff-tree or Bittersweet family...
# 1646  Ericaceae [Heath or Blueberry family], e.g. rh...
# 1647  Euphorbiaceae [Spurge family], e.g. ricinus [c...
#
#                                                title_fr creation_date  size  \
# 629   Appareils pour la récolte non prévus dans les ...    20090101.0     1
# 1639                                             Algues    20090101.0     1
# 1640  Pteridophyta [fougères et apparentés]; Filicop...    20090101.0     1
# 1641         Coniferophyta [gymnospermes], p.ex. cyprès    20090101.0     1
# 1642                      Magnoliopsida [dicotylédones]    20090101.0    16
# 1643  Apiaceae ou Umbelliferae [famille de la carott...    20090101.0     1
# 1644  Asteraceae ou Compositae [famille de l'aster o...    20090101.0     1
# 1645  Celastraceae [famille du bourreau des arbres o...    20090101.0     1
# 1646  Ericaceae [famille de la bruyère ou de la myrt...    20090101.0     1
# 1647  Euphorbiaceae [famille de l'euphorbe], p.ex. R...    20090101.0     1
#
#       size_percent
# 629          0.001
# 1639         0.001
# 1640         0.001
# 1641         0.001
# 1642         0.021
# 1643         0.001
# 1644         0.001
# 1645         0.001
# 1646         0.001
# 1647         0.001
# -------------------------------- 20100101.0
# (402, 11)
#                symbol kind          parent  level symbol_short parent_short  \
# 649    A01F0007700000    1  A01F0007000000      6      A01F7/7     A01F7/00
# 726    A01F0029090000    1  A01F0029000000      6    A01F29/09    A01F29/00
# 3795   A44B0099000000    m            A44B      5    A44B99/00         A44B
# 8527   A62C0099000000    m            A62C      5    A62C99/00         A62C
# 10775  B01L0007040000    1  B01L0007000000      6     B01L7/04     B01L7/00
# 10780  B01L0099000000    m            B01L      5    B01L99/00         B01L
# 14829  B24D0099000000    m            B24D      5    B24D99/00         B24D
# 16907  B29D0033000000    m            B29D      5    B29D33/00         B29D
# 16908  B29D0035000000    m            B29D      5    B29D35/00         B29D
# 16909  B29D0035020000    1  B29D0035000000      6    B29D35/02    B29D35/00
#
#                                                 title_en  \
# 649                                          with flails
# 726                                              Details
# 3795   Subject matter not provided for in other group...
# 8527   Subject matter not provided for in other group...
# 10775   Heat insulating devices, e.g. jackets for flasks
# 10780  Subject matter not provided for in other group...
# 14829  Subject matter not provided for in other group...
# 16907                      Producing bushes for bearings
# 16908                                 Producing footwear
# 16909  made in one piece using a moulding technique, ...
#
#                                                 title_fr creation_date  size  \
# 649                                      avec des fléaux    20100101.0     1
# 726                                Parties constitutives    20100101.0     7
# 3795   Matière non prévue dans les autres groupes de ...    20100101.0     1
# 8527   Matière non prévue dans les autres groupes de ...    20100101.0     1
# 10775  Dispositifs d'isolation thermique, p.ex. manch...    20100101.0     1
# 10780  Matière non prévue dans les autres groupes de ...    20100101.0     1
# 14829  Matière non prévue dans les autres groupes de ...    20100101.0     1
# 16907                   Fabrication de bagues de paliers    20100101.0     1
# 16908                          Fabrication de chaussures    20100101.0     8
# 16909  fabriquées d'une seule pièce en utilisant une ...    20100101.0     2
#
#        size_percent
# 649           0.001
# 726           0.009
# 3795          0.001
# 8527          0.001
# 10775         0.001
# 10780         0.001
# 14829         0.001
# 16907         0.001
# 16908         0.011
# 16909         0.003
# -------------------------------- 19900101.0
# (7180, 11)
#              symbol kind          parent  level symbol_short parent_short  \
# 671  A01F0012385000    2  A01F0012300000      7   A01F12/385     A01F12/3
# 672  A01F0012390000    2  A01F0012300000      7    A01F12/39     A01F12/3
# 673  A01F0012395000    2  A01F0012300000      7   A01F12/395     A01F12/3
# 693  A01F0015070000    1  A01F0015000000      6    A01F15/07    A01F15/00
# 843  A01G0023081000    3  A01G0023080000      8   A01G23/081    A01G23/08
# 844  A01G0023083000    3  A01G0023080000      8   A01G23/083    A01G23/08
# 845  A01G0023085000    4  A01G0023083000      9   A01G23/085   A01G23/083
# 846  A01G0023087000    3  A01G0023080000      8   A01G23/087    A01G23/08
# 847  A01G0023089000    4  A01G0023087000      9   A01G23/089   A01G23/087
# 848  A01G0023090000    4  A01G0023087000      9    A01G23/09   A01G23/087
#
#                                               title_en  \
# 671               with endless straw-conveying surface
# 672  with straw carriers in the form of rotors or d...
# 673  Conical or cylindrical straw separators with i...
# 693  Rotobalers, i.e. machines for forming cylindri...
# 843  Feller-bunchers, i.e. with bunching by felling...
# 844                                   Feller-delimbers
# 845  having the shearing head mounted on a first bo...
# 846  Shearing apparatus or the like specially adapt...
# 847                          having two or more shears
# 848                             of the percussion type
#
#                                               title_fr creation_date  size  \
# 671  avec une surface sans fin de transport de la p...    19900101.0     1
# 672  avec des transporteurs de la paille en forme d...    19900101.0     1
# 673  Séparateurs de paille coniques ou cylindriques...    19900101.0     1
# 693  Presses enrouleuses, c. à d. machines pour for...    19900101.0     1
# 843  Abatteuses-botteleuses, c. à d. avec bottelage...    19900101.0     1
# 844                            Abatteuses-ébrancheuses    19900101.0     2
# 845  avec la tête de cisaillement montée sur une pr...    19900101.0     1
# 846  Appareils de cisaillement ou analogues spécial...    19900101.0     3
# 847                           avec plusieurs cisailles    19900101.0     1
# 848                               du type à percussion    19900101.0     1
#
#      size_percent
# 671         0.001
# 672         0.001
# 673         0.001
# 693         0.001
# 843         0.001
# 844         0.003
# 845         0.001
# 846         0.004
# 847         0.001
# 848         0.001
# -------------------------------- 20180101.0
# (1046, 11)
#              symbol kind          parent  level symbol_short parent_short  \
# 734  A01G0002000000    m            A01G      5     A01G2/00         A01G
# 735  A01G0002100000    1  A01G0002000000      6      A01G2/1     A01G2/00
# 736  A01G0002200000    1  A01G0002000000      6      A01G2/2     A01G2/00
# 737  A01G0002300000    1  A01G0002000000      6      A01G2/3     A01G2/00
# 738  A01G0002320000    2  A01G0002300000      7     A01G2/32      A01G2/3
# 739  A01G0002350000    2  A01G0002300000      7     A01G2/35      A01G2/3
# 740  A01G0002380000    2  A01G0002300000      7     A01G2/38      A01G2/3
# 761  A01G0009029000    2  A01G0009020000      7    A01G9/029     A01G9/02
# 762  A01G0009033000    2  A01G0009020000      7    A01G9/033     A01G9/02
# 774  A01G0009280000    1  A01G0009000000      6     A01G9/28     A01G9/00
#
#                                               title_en  \
# 734  Vegetative propagation (plant reproduction by ...
# 735                               by means of cuttings
# 736                                           Layering
# 737             Grafting (grafting-wax A01N0003040000)
# 738                       Automatic apparatus therefor
# 739                                 Cutting; Inserting
# 740                                  Holding; Ligating
# 761  Receptacles for seedlings (growth substrates i...
# 762  Flat containers for turf, lawn or the like, e....
# 774  Raised beds; Planting beds; Edging elements fo...
#
#                                               title_fr creation_date  size  \
# 734  Propagation végétative (reproduction de plante...    20180101.0     7
# 735                                          Bouturage    20180101.0     1
# 736                                         Marcottage    20180101.0     1
# 2326  par fermentation de produits naturels, p.ex. d...    20160101.0     1
# 2327  Prétraitement de produits alimentaires avec de...    20160101.0     1
# 2328  Ajout de micro-organismes ou de leurs produits...    20160101.0     2
# 2329                        de micro-organismes vivants    20160101.0     1
# 2330  à base de matières d’origine animale (obtenus ...    20160101.0     5
# 2331                                  à base de poisson    20160101.0     1
# 2332                                     à base de sang    20160101.0     1
# 2333  à base de matières résiduelles, p.ex. de plume...    20160101.0     2
#
#       size_percent
# 2324         0.024
# 2325         0.007
# 2326         0.001
# 2327         0.001
# 2328         0.003
# 2329         0.001
# 2330         0.007
# 2331         0.001
# 2332         0.001
# 2333         0.003
# -------------------------------- 20190101.0
# (669, 11)
#               symbol kind          parent  level symbol_short parent_short  \
# 3133  A41D0031040000    1  A41D0031000000      6    A41D31/04    A41D31/00
# 3134  A41D0031060000    2  A41D0031040000      7    A41D31/06    A41D31/04
# 3135  A41D0031080000    2  A41D0031040000      7    A41D31/08    A41D31/04
# 3136  A41D0031100000    2  A41D0031040000      7     A41D31/1    A41D31/04
# 3137  A41D0031102000    3  A41D0031100000      8   A41D31/102     A41D31/1
# 3138  A41D0031120000    2  A41D0031040000      7    A41D31/12    A41D31/04
# 3139  A41D0031140000    2  A41D0031040000      7    A41D31/14    A41D31/04
# 3140  A41D0031180000    2  A41D0031040000      7    A41D31/18    A41D31/04
# 3141  A41D0031240000    2  A41D0031040000      7    A41D31/24    A41D31/04
# 3142  A41D0031260000    2  A41D0031040000      7    A41D31/26    A41D31/04
#
#                                                title_en  \
# 3133           characterised by special function or use
# 3134              Thermally protective, e.g. insulating
# 3135                     Heat resistant; Fire retardant
# 3136  Impermeable to liquids, e.g. waterproof; Liqui...
# 3137                          Waterproof and breathable
# 3138                       Hygroscopic; Water retaining
# 3139  Air permeable, i.e. capable of being penetrate...
# 3140                                            Elastic
# 3141  Resistant to mechanical stress, e.g. pierce-proof
# 3142  Electrically protective, e.g. preventing stati...
#
#                                                title_fr creation_date  size  \
# 3133  caractérisés par une fonction ou une utilisati...    20190101.0    13
# 3134               Protection thermique, p.ex. isolants    20190101.0     1
# 3135                 résistants à la chaleur; ignifuges    20190101.0     1
# 3136  imperméables aux liquides, p.ex. à l’eau; repo...    20190101.0     2
# 3137                         imperméables et respirants    20190101.0     1
# 3138                   hygroscopiques; rétenteurs d'eau    20190101.0     1
# 3139  perméables à l’air, c. à d. capables d’être pé...    20190101.0     1
# 3140                                         élastiques    20190101.0     1
# 3141  résistants à la contrainte mécanique, p.ex. ré...    20190101.0     1
# 3142  Protection électrique, p.ex. prévention de l'é...    20190101.0     1
#
#       size_percent
# 3133         0.017
# 3134         0.001
# 3135         0.001
# 3136         0.003
# 3137         0.001
# 3138         0.001
# 3139         0.001
# 3140         0.001
# 3141         0.001
# 3142         0.001
# -------------------------------- 20080401.0
# (25, 11)
#                symbol kind          parent  level symbol_short parent_short  \
# 3577   G05G0001440000    2  G05G0001300000      7     G05G1/44      G05G1/3
# 63012  G05G0001445000    3  G05G0001440000      8    G05G1/445     G05G1/44
# 63929  G05G0001420000    2  G05G0001300000      7     G05G1/42      G05G1/3
# 64038  G05G0001380000    2  G05G0001300000      7     G05G1/38      G05G1/3
# 64039  G05G0001400000    2  G05G0001300000      7      G05G1/4      G05G1/3
# 64049  G05G0001010000    1  G05G0001000000      6     G05G1/01     G05G1/00
# 64050  G05G0001015000    1  G05G0001000000      6    G05G1/015     G05G1/00
# 64057  G05G0001300000    1  G05G0001000000      6      G05G1/3     G05G1/00
# 64058  G05G0001320000    2  G05G0001300000      7     G05G1/32      G05G1/3
# 64059  G05G0001323000    3  G05G0001320000      8    G05G1/323     G05G1/32
#
#                                                 title_en  \
# 3577                                            pivoting
# 63012                            about a central fulcrum
# 63929                         non-pivoting, e.g. sliding
# 64038  comprising means to continuously detect pedal ...
# 64039                                         adjustable
# 64049  Arrangements of two or more controlling member...
# 64050  Arrangements for indicating the position of a ...
# 64057               Controlling members actuated by foot
# 64058                       with means to prevent injury
# 64059  means disconnecting the connection between ped...
#
#                                                 title_fr creation_date  size  \
# 3577                                           pivotants    20080401.0     2
# 63012                          autour d'un pivot central    20080401.0     1
# 63929                   non pivotants, p.ex. coulissants    20080401.0     1
# 64038  comprenant des moyens pour détecter en continu...    20080401.0     1
# 64039                                          réglables    20080401.0     2
# 64049  Agencements de plusieurs organes de commande l...    20080401.0     1
# 64050  Agencements pour indiquer la position d'un org...    20080401.0     1
# 64057          Organes de commande actionnés par le pied    20080401.0    17
# 64058          avec des moyens pour éviter les blessures    20080401.0     3
# 64059  moyens pour interrompre la liaison entre la pé...    20080401.0     1
#
#        size_percent
# 3577          0.003
# 63012         0.001
# 63929         0.001
# 64038         0.001
# 64039         0.003
# 64049         0.001
# 64050         0.001
# 64057         0.023
# 64058         0.004
# 64059         0.001
# -------------------------------- 20130101.0
# (615, 11)
#               symbol kind          parent  level symbol_short parent_short  \
# 4635  A47C0001035500    5  A47C0001035000     10   A47C1/0355    A47C1/035
# 6313  A61F0002070000    4  A61F0002060000      9     A61F2/07     A61F2/06
# 6352  A61F0002844000    2  A61F0002820000      7    A61F2/844     A61F2/82
# 6353  A61F0002848000    2  A61F0002820000      7    A61F2/848     A61F2/82
# 6354  A61F0002852000    2  A61F0002820000      7    A61F2/852     A61F2/82
# 6355  A61F0002856000    2  A61F0002820000      7    A61F2/856     A61F2/82
# 6358  A61F0002890000    3  A61F0002860000      8     A61F2/89     A61F2/86
# 6360  A61F0002910000    4  A61F0002900000      9     A61F2/91      A61F2/9
# 6361  A61F0002915000    5  A61F0002910000     10    A61F2/915     A61F2/91
# 6363  A61F0002930000    3  A61F0002920000      8     A61F2/93     A61F2/92
#
#                                                title_en  \
# 4635   actuated by linkages, e.g. lazy-tongs mechanisms
# 6313                                       Stent-grafts
# 6352                         folded prior to deployment
# 6353  having means for fixation to the vessel wall, ...
# 6354            Two or more distinct overlapping stents
# 6355      Single tubular stent with side portal passage
# 6358  the wire-like elements comprising two or more ...
# 6360  made from perforated sheets or tubes, e.g. per...
# 6361  with bands having a meander structure, adjacen...
# 6363  circumferentially expandable by using ratcheti...
#
#                                                title_fr creation_date  size  \
# 4635  actionnés par des tringles, p.ex. à mécanisme ...    20130101.0     1
 11)
#               symbol kind          parent  level symbol_short parent_short  \
# 8097  A61M0099000000    m            A61M      5    A61M99/00         A61M
# 8991  A63C0010200000    2  A63C0010160000      7     A63C10/2    A63C10/16
# 9014  A63C0010000000    m            A63C      5    A63C10/00         A63C
# 9015  A63C0010020000    1  A63C0010000000      6    A63C10/02    A63C10/00
# 9016  A63C0010040000    2  A63C0010020000      7    A63C10/04    A63C10/02
# 9017  A63C0010060000    3  A63C0010040000      8    A63C10/06    A63C10/04
# 9018  A63C0010080000    2  A63C0010020000      7    A63C10/08    A63C10/02
# 9019  A63C0010100000    2  A63C0010020000      7     A63C10/1    A63C10/02
# 9020  A63C0010120000    1  A63C0010000000      6    A63C10/12    A63C10/00
# 9021  A63C0010140000    1  A63C0010000000      6    A63C10/14    A63C10/00
#
#                                                title_en  \
# 8097  Subject matter not provided for in other group...
# 8991  in longitudinal or lateral direction relative ...
# 9014                                 Snowboard bindings
# 9015       characterised by details of the shoe holders
# 9016             Shoe holders for passing over the shoe
# 9017            Straps therefor, e.g. adjustable straps
# 9018                       Toe or heel stirrups; Clamps
# 9019  using parts which are fixed on the shoe, e.g. ...
# 9020  Yieldable or self-releasing in the event of an...
# 9021           Interfaces, e.g. in the shape of a plate
#
#                                                title_fr creation_date  size  \
# 8097  Matière non prévue dans les autres groupes de ...    20120101.0     1
# 8991  en direction longitudinale ou latérale par rap...    20120101.0     1
# 9014                      Fixations de surfs des neiges    20120101.0    15
# 9015  caractérisées par des parties constitutives du...    20120101.0     5
# 9016           à sangles ou capot coiffant la chaussure    20120101.0     2
# 9017      Sangles à cet effet, p.ex. sangles ajustables    20120101.0     1
# 9018        Étriers avant ou arrière; Brides de serrage    20120101.0     1
# 9019  utilisant des éléments fixés à la chaussure, p...    20120101.0     1
# 9020  se relâchant ou se détachant d'elles-mêmes en ...    20120101.0     1
# 9021          Interfaces, p.ex. sous la forme de plaque    20120101.0     1
#
#       size_percent
# 8097         0.001
# 8991         0.001
# 9014         0.020
# 9015         0.007
# 9016         0.003
# 9017         0.001
# 9018         0.001
# 9019         0.001
# 9020         0.001
# 9021         0.001
# -------------------------------- 20070101.0
# (61, 11)
#               symbol kind          parent  level symbol_short parent_short  \
# 8535  A62D0003020000    1  A62D0003000000      6     A62D3/02     A62D3/00
# 8536  A62D0003100000    1  A62D0003000000      6      A62D3/1     A62D3/00
# 8537  A62D0003110000    2  A62D0003100000      7     A62D3/11      A62D3/1
# 8538  A62D0003115000    3  A62D0003110000      8    A62D3/115     A62D3/11
# 8539  A62D0003130000    2  A62D0003100000      7     A62D3/13      A62D3/1
# 8540  A62D0003150000    2  A62D0003100000      7     A62D3/15      A62D3/1
# 8541  A62D0003170000    2  A62D0003100000      7     A62D3/17      A62D3/1
# 8542  A62D0003172000    3  A62D0003170000      8    A62D3/172     A62D3/17
# 8543  A62D0003174000    3  A62D0003170000      8    A62D3/174     A62D3/17
# 8544  A62D0003176000    3  A62D0003170000      8    A62D3/176     A62D3/17
#
#                                                title_en  \
# 8535  by biological methods, i.e. processes using en...
# 8536  by subjecting to electric or wave energy or pa...
# 8537    Electrochemical processes, e.g. electrodialysis
# 8538             Electrolytic degradation or conversion
# 8539                                    to sonic energy
# 8540  to particle radiation, e.g. electron beam radi...
# 8541  to electromagnetic radiation, e.g. emitted by ...
# 8542  Gamma rays, i.e. radiation having a wavelength...
# 8543  X-rays, i.e. radiation having a wavelength of ...
# 8544  Ultraviolet radiation, i.e. radiation having a...
#
#                                                title_fr creation_date  size  \
# 8535  par des procédés biologiques, c. à d. des proc...    20070101.0     1
# 8536  par exposition à une énergie électrique ou ond...    20070101.0    11
# 8537    Procédés électrochimiques, p.ex. électrodialyse    20070101.0     2
# 8538           Dégradation ou conversion électrolytique    20070101.0     1
# 8539                              à une énergie sonique    20070101.0     1
# 8540  à un rayonnement particulaire, p.ex. à un fais...    20070101.0     1
# 8541  à un rayonnement électromagnétique, p.ex. émis...    20070101.0     5
# 8542  Rayons gamma, c. à d. rayonnement présentant u...    20070101.0     1
# 8543  Rayons X, c. à d. rayonnement présentant une l...    20070101.0     1
# 8544  Rayonnement ultraviolet, c. à d. rayonnement p...    20070101.0     1
#
#       size_percent
# 8535         0.001
# 8536         0.015
# 8537         0.003
# 8538         0.001
# 8539         0.001
# 8540         0.001
# 8541         0.007
# 8542         0.001
# 8543         0.001
# 8544         0.001
# -------------------------------- 20140101.0
# (629, 11)
#               symbol kind          parent  level symbol_short parent_short  \
# 9149  A63F0013200000    1  A63F0013000000      6     A63F13/2    A63F13/00
# 9150  A63F0013210000    2  A63F0013200000      7    A63F13/21     A63F13/2
# 9151  A63F0013211000    3  A63F0013210000      8   A63F13/211    A63F13/21
# 9152  A63F0013212000    3  A63F0013210000      8   A63F13/212    A63F13/21
# 9153  A63F0013213000    3  A63F0013210000      8   A63F13/213    A63F13/21
# 9154  A63F0013214000    3  A63F0013210000      8   A63F13/214    A63F13/21
# 9155  A63F0013214500    4  A63F0013214000      9  A63F13/2145   A63F13/214
# 9156  A63F0013215000    3  A63F0013210000      8   A63F13/215    A63F13/21
# 9157  A63F0013216000    3  A63F0013210000      8   A63F13/216    A63F13/21
# 9158  A63F0013217000    3  A63F0013210000      8   A63F13/217    A63F13/21
#
#                                                title_en  \
# 9149          Input arrangements for video game devices
# 9150  characterised by their sensors, purposes or types
# 9151  using inertial sensors, e.g. accelerometers or...
# 9152  using sensors worn by the player, e.g. for mea...
# 9153  comprising photodetecting means, e.g. cameras,...
# 9154  for locating contacts on a surface, e.g. floor...
# 9155  the surface being also a display device, e.g. ...
# 9156  comprising means for detecting acoustic signal...
# 9157  using geographical information, e.g. location ...
# 9158  using environment-related information, i.e. in...
#
#                                                title_fr creation_date  size  \
# 9149  Dispositions d'entrée pour les dispositifs de ...    20140101.0    17
# 9150  caractérisées par leurs capteurs, leurs finali...    20140101.0    11
# 9151  utilisant des capteurs d’inertie, p.ex. des ac...    20140101.0     1
# 9152  utilisant des capteurs portés par le joueur, p...    20140101.0     1
# 9153  comprenant des moyens de photo-détection, p.ex...    20140101.0     1
# 9154  pour localiser des contacts sur une surface, p...    20140101.0     2
# 9155  la surface étant aussi un dispositif d’afficha...    20140101.0     1
# 9156  comprenant des moyens de détection des signaux...    20140101.0     1
# 9157  utilisant des informations géographiques, p.ex...    20140101.0     1
# 9158  utilisant des informations liées à l’environne...    20140101.0     1
#
#       size_percent
# 9149         0.023
# 9150         0.015
# 9151         0.001
# 9152         0.001
# 9153         0.001
# 9154         0.003
# 9155         0.001
# 9156         0.001
# 9157         0.001
# 9158         0.001
# -------------------------------- 20071001.0
# (28, 11)
#                symbol kind          parent  level symbol_short parent_short  \
# 20569  B60K0006200000    1  B60K0006000000      6      B60K6/2     B60K6/00
# 20570  B60K0006220000    2  B60K0006200000      7     B60K6/22      B60K6/2
# 20571  B60K0006240000    3  B60K0006220000      8     B60K6/24     B60K6/22
# 20572  B60K0006260000    3  B60K0006220000      8     B60K6/26     B60K6/22
# 20574  B60K0006280000    3  B60K0006220000      8     B60K6/28     B60K6/22
# 20575  B60K0006300000    3  B60K0006220000      8      B60K6/3     B60K6/22
# 20576  B60K0006320000    3  B60K0006220000      8     B60K6/32     B60K6/22
# 20577  B60K0006340000    3  B60K0006220000      8     B60K6/34     B60K6/22
# 20578  B60K0006360000    3  B60K0006220000      8     B60K6/36     B60K6/22
# 20579  B60K0006365000    4  B60K0006360000      9    B60K6/365     B60K6/36
#
#                                                 title_en  \
# 20569  the prime-movers consisting of electric motors...
# 20570  characterised by apparatus, components or mean...
# 20571            characterised by the combustion engines
# 20572      characterised by the motors or the generators
# 20574  characterised by the electric energy storing m...
# 20575  characterised by chargeable mechanical accumul...
# 20576                    characterised by the fuel cells
# 20577  characterised by the absence of energy storing...
# 20578         characterised by the transmission gearings
# 20579               with the gears having orbital motion
#
#                                                 title_fr creation_date  size  \
# 20569  les moteurs primaires étant constitués de mote...    20071001.0    28
# 20570  caractérisés par des appareils, des organes ou...    20071001.0    14
# 20571          caractérisés par les moteurs à combustion    20071001.0     1
# 20572    caractérisés par les moteurs ou les générateurs    20071001.0     1
# 20574  caractérisés par les moyens d'accumulation d'é...    20071001.0     1
# 20575  caractérisés par des accumulateurs mécaniques ...    20071001.0     1
# 20576           caractérisés par les piles à combustible    20071001.0     1
# 20577  caractérisés par l'absence de moyens d'accumul...    20071001.0     1
# 20578    caractérisés par les transmissions à engrenages    20071001.0     2
# 20579    les pignons étant animés d'un mouvement orbital    20071001.0     1
#
#        size_percent
# 20569         0.038
# 20570         0.019
# 20571         0.001
# 20572         0.001
# 20574         0.001
# 20575         0.001
# 20576         0.001
# 20577         0.001
# 20578         0.003
# 20579         0.001
# -------------------------------- 20080101.0
# (146, 11)
#                symbol kind          parent  level symbol_short parent_short  \
# 74587  H04H0020020000    1  H04H0020000000      6    H04H20/02    H04H20/00
# 74588  H04H0020040000    2  H04H0020020000      7    H04H20/04    H04H20/02
# 74589  H04H0020060000    2  H04H0020020000      7    H04H20/06    H04H20/02
# 74590  H04H0020080000    2  H04H0020020000      7    H04H20/08    H04H20/02
# 74591  H04H0020100000    1  H04H0020000000      6     H04H20/1    H04H20/00
# 74592  H04H0020120000    1  H04H0020000000      6    H04H20/12    H04H20/00
# 74593  H04H0020140000    2  H04H0020120000      7    H04H20/14    H04H20/12
# 74594  H04H0020160000    1  H04H0020000000      6    H04H20/16    H04H20/00
# 74595  H04H0020180000    1  H04H0020000000      6    H04H20/18    H04H20/00
# 74596  H04H0020200000    1  H04H0020000000      6     H04H20/2    H04H20/00
#
#                                                 title_en  \
# 74587    Arrangements for relaying broadcast information
# 74588                      from field pickup units [FPU]
# 74589                           among broadcast stations
# 74590                             among terminal devices
# 74591  Arrangements for replacing or switching inform...
# 74592  Arrangements for monitoring, testing or troubl...
# 74593                          for monitoring programmes
# 74594  Arrangements for broadcast or distribution of ...
# 74595  Arrangements for synchronising broadcast or di...
# 74596  Arrangements for broadcast or distribution of ...
#
#                                                 title_fr creation_date  size  \
# 74587  Dispositions pour la retransmission des inform...    20080101.0     4
# 74588          à partir d’appareils d’émission en direct    20080101.0     1
# 74589               entre des stations de radiodiffusion    20080101.0     1
# 74590                      entre des appareils terminaux    20080101.0     1
# 74591  Dispositions pour le remplacement ou la commut...    20080101.0     1
# 74592  Dispositions de contrôle, de test ou de dépannage    20080101.0     2
# 74593                         de contrôle des programmes    20080101.0     1
# 74594  Dispositions de radiodiffusion ou de distribut...    20080101.0     1
# 74595  Dispositions de synchronisation de la radiodif...    20080101.0     1
# 74596  Dispositions de radiodiffusion ou de distribut...    20080101.0     3
#
#        size_percent
# 74587         0.005
# 74588         0.001
# 74589         0.001
# 74590         0.001
# 74591         0.001
# 74592         0.003
# 74593         0.001
# 74594         0.001
# 74595         0.001
# 74596         0.004

# %%
df = pd.read_sql_table('cpc', engine, schema='patent_classification')
print(df.shape)
print(df.dtypes)
print(df.head(5))
# Out:
# (180118, 8)
# symbol_short     object
# symbol           object
# kind             object
# parent           object
# level            object
# parent_short     object
# title_en         object
# creation_date    object
# dtype: object
#   symbol_short symbol kind parent level parent_short  \
# 0            A      A    s    CPC     2          CPC
# 1            B      B    s    CPC     2          CPC
# 2            C      C    s    CPC     2          CPC
# 3            D      D    s    CPC     2          CPC
# 4            E      E    s    CPC     2          CPC
#
#                               title_en creation_date
# 0                    HUMAN NECESSITIES    2013-01-01
# 1  PERFORMING OPERATIONS; TRANSPORTING    2013-01-01
# 2                CHEMISTRY; METALLURGY    2013-01-01
# 3                      TEXTILES; PAPER    2013-01-01
# 4                  FIXED CONSTRUCTIONS    2013-01-01

# %%
print(len(df[df.duplicated(subset='symbol')]))
# Out:
# 0

# %%
df = pd.read_sql_table('cpc', engine, schema='patent_classification')
grouped_level = df.groupby('level')

pathsL = []

# iterte df over rows
for index, row in df.iterrows():
    key = row['symbol']
    level = int(row['level'])

    # select only symbols of main groups and subgroups
    if level >4:
        path=[key]
        # trace path by appending successively the corresponding direct parent to a list
        for i in range(level , 2, -1):
            group = grouped_level.get_group(i)
            try:
                parent = group[group['symbol'] == key]['parent'].iloc[0]
                key = parent
                path.append(parent)
            except:
                print(key, level)
                pass
        path = path[::-1]
        pathsL.append(path)
paths_df = pd.DataFrame(pathsL)
# Out:
# A01D0101000000 5
# A01D0101000000 5
# A01F0025000000 5
# A01F0025000000 5
# A47C0020000000 7
# C09K0109000000 5
# C10M0101000000 5
# C10M0101000000 5
# C10M0103000000 5
# C10M0103000000 5
# C10M0105000000 5
# C10M0105000000 5
# C10M0107000000 5
# C10M0107000000 5
# C10N0010000000 5
# C10N0010000000 5
# C10N0020000000 5
# C10N0020000000 5
# C10N0030000000 5
# C10N0030000000 5
# C10N0040000000 5
# C10N0040000000 5
# C10N0050000000 5
# C10N0050000000 5
# C10N0060000000 5
# C10N0060000000 5
# C10N0070000000 5
# C10N0070000000 5
# C10N0080000000 5
# C10N0080000000 5
# C12C0003000000 5
# C12C0003000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C12M0001000000 5
# C22B0003000000 7
# C22B0003000000 7
# C22B0003000000 7
# D06M0013000000 5
# D06M0013000000 5
# D06M0101000000 5
# D06M0101000000 5
# D21H0017000000 5
# D21H0017000000 5
# D21H0027000000 5
# D21H0027000000 5
# D21H0027000000 5
# D21H0027000000 5
# E01D0101000000 5
# E01D0101000000 5
# E05C0017000000 7
# E21B0001000000 5
# E21B0001000000 5
# E21B0003000000 5
# E21B0003000000 5
# E21B0015000000 5
# E21B0015000000 5
# E21B0021000000 5
# E21B0021000000 5
# F04B0037000000 5
# F04B0037000000 5
# F16D0121000000 5
# F16D0121000000 5
# F16D0123000000 5
# F16D0123000000 5
# F16D0125000000 5
# F16D0125000000 5
# F16D0127000000 5
# F16D0127000000 5
# F16D0129000000 5
# F16D0129000000 5
# F16D0131000000 5
# F16D0131000000 5
# F16K0011000000 5
# F16K0011000000 5
# F16L0101000000 5
# F16L0101000000 5
# F21V0001000000 5
# F21V0001000000 5
# F21V0001000000 5
# F21V0001000000 5
# F21V0001000000 5
# F21V0001000000 5
# F21V0001000000 5
# F21V0001000000 5
# F21V0001000000 5
# F21V0001000000 5
# F21W0102000000 5
# F21W0102000000 5
# F21W0103000000 5
# F21W0103000000 5
# F21W0104000000 5
# F21W0104000000 5
# F21W0105000000 5
# F21W0105000000 5
# F21W0106000000 5
# F21W0106000000 5
# F21W0107000000 5
# F21W0107000000 5
# F21W0111000000 5
# F21W0111000000 5
# F21W0121000000 5
# F21W0121000000 5
# F21W0131000000 5
# F21W0131000000 5
# F21Y0101000000 5
# F21Y0101000000 5
# F21Y0103000000 5
# F21Y0103000000 5
# F21Y0105000000 5
# F21Y0105000000 5
# F21Y0107000000 5
# F21Y0107000000 5
# F21Y0109000000 5
# F21Y0109000000 5
# F21Y0111000000 5
# F21Y0111000000 5
# F21Y0113000000 5
# F21Y0113000000 5
# F21Y0115000000 5
# F21Y0115000000 5
# F23B0020000000 5
# F23B0020000000 5
# F23B0030000000 5
# F23B0030000000 5
# F23B0030000000 5
# F23B0030000000 5
# F23B0030000000 5
# F23B0030000000 5
# F23B0101000000 5
# F23B0101000000 5
# F23B0103000000 5
# F23B0103000000 5
# F23D0099000000 5
# F23D0099000000 5
# F24F0110000000 5
# F24F0110000000 5
# F24F0120000000 5
# F24F0120000000 5
# F24F0130000000 5
# F24F0130000000 5
# F24F0140000000 5
# F24F0140000000 5
# G01C0019000000 5
# G01C0019000000 5
# G01N0030000000 8
# G01N0030000000 8
# G02B0023000000 7
# G07D0005000000 5
# G07D0005000000 5
# G09F0003000000 7
# G09F0003000000 7
# G09F0003000000 7
# G09F0003000000 7
# G09F0003000000 7
# H01L0023000000 5
# H01L0023000000 5
# H01R0101000000 5
# H01R0101000000 5
# H01R0103000000 5
# H01R0103000000 5
# H01R0105000000 5
# H01R0105000000 5
# H01R0107000000 5
# H01R0107000000 5
# H02P0101000000 5
# H02P0101000000 5
# H02P0103000000 5
# H02P0103000000 5
# H03F0099000000 5
# H03F0099000000 5
# H03H0015000000 7
# H04J0099000000 5
# H04J0099000000 5
# H04N0101000000 5
# H04N0101000000 5
# A23G0003340000 6
# A23G0003340000 6
# A23G0003340000 6
# A47C0007620000 8
# A47C0020000000 8
# A47G0019020000 8
# A63B0102000000 6
# A63B0102000000 6
# A63B0102000000 6
# A63B0102000000 6
# A63B0102000000 6
# A63B0102000000 6
# A61B0005145000 6
# A61B0005145000 6
# A61B0005145000 6
# A61B0008080000 6
# A61B0008080000 6
# A61B0008080000 6
# A61B0008080000 6
# A61B0008080000 6
# A61B0008080000 6
# A61B0017225000 8
# A61B0017225000 8
# A61B0017225000 8
# A61C0013107000 6
# A61C0013107000 6
# A61C0013107000 6
# A61C0017060000 6
# A61C0017060000 6
# A61C0017060000 6
# A61F0002000900 7
# A61F0002000900 7
# A61F0002000900 7
# A61F0002000900 7
# A61F0002000900 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-f2f0504e107f> in <module>
#      14         # trace path by appending successively the corresponding direct parent to a list
#      15         for i in range(level , 2, -1):
# ---> 16             group = grouped_level.get_group(i)
#      17             try:
#      18                 parent = group[group['symbol'] == key]['parent'].iloc[0]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in get_group(self, name, obj)
#     877             raise KeyError(name)
#     878
# --> 879         return obj._take(inds, axis=self.axis)
#     880
#     881     def __iter__(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in _take(self, indices, axis, is_copy)
#    2787         new_data = self._data.take(indices,
#    2788                                    axis=self._get_block_manager_axis(axis),
# -> 2789                                    verify=True)
#    2790         result = self._constructor(new_data).__finalize__(self)
#    2791
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/internals.py in take(self, indexer, axis, verify, convert)
#    4528         n = self.shape[axis]
#    4529         if convert:
# -> 4530             indexer = maybe_convert_indices(indexer, n)
#    4531
#    4532         if verify:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in maybe_convert_indices(indices, n)
#    2477
#    2478     mask = (indices >= n) | (indices < 0)
# -> 2479     if mask.any():
#    2480         raise IndexError("indices are out-of-bounds")
#    2481     return indices
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/core/_methods.py in _any(a, axis, dtype, out, keepdims)
#      41
#      42 def _any(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 43     return umr_any(a, axis, dtype, out, keepdims)
#      44
#      45 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
df = pd.read_sql_table('ipc', engine, schema='patent_classification')
dateL = list(df['creation_date'].unique())
dateL = sorted([int(str(date)[:4]) for date in dateL])
print(dateL)
# Out:
# [1968, 1974, 1980, 1985, 1990, 1995, 2000, 2006, 2007, 2007, 2008, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
df = pd.read_sql_table('ipc', engine, schema='patent_classification')
print(df.shape)
# Out:
# (75287, 12)

# %%
grouped = df.groupby('creation_date')
keys = list(grouped.groups.keys())
for key in keys:
    group = grouped.get_group(key)
    print(key, group.shape)
# Out:
# 19680901 (39374, 12)
# 19740701 (6271, 12)
# 19800101 (5608, 12)
# 19850101 (4187, 12)
# 19900101 (7117, 12)
# 19950101 (2824, 12)
# 20000101 (1658, 12)
# 20060101 (1307, 12)
# 20070101 (58, 12)
# 20071001 (28, 12)
# 20080101 (146, 12)
# 20080401 (25, 12)
# 20090101 (291, 12)
# 20100101 (402, 12)
# 20110101 (493, 12)
# 20120101 (501, 12)
# 20130101 (615, 12)
# 20140101 (626, 12)
# 20150101 (336, 12)
# 20160101 (1027, 12)
# 20170101 (684, 12)
# 20180101 (1040, 12)
# 20190101 (669, 12)
